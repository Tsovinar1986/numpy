# %%
import numpy as np
arr1 = np.array([123,456,897,98]) 
arr2 = np.array([34,67,456,590])
res = arr1 + arr2
res
# Out:
# array([ 157,  523, 1353,  688])

# %%
import numpy as np
x = np.array([[2,4,6],[5,6,7]])
y = np.array(3)
res = x * y
res
# Out:
# array([[ 6, 12, 18],
#        [15, 18, 21]])

# %%
import numpy as np
x = np.array([5,6,8,9,10,12])
new_arr = x.reshape(2,3)
new_arr
# Out:
# array([[ 5,  6,  8],
#        [ 9, 10, 12]])

# %%
import numpy as np
x = np.array([2.5,3.5,4.5,5.5])
new_arr = x.astype('i')
print(new_arr)
# Out:
# [2 3 4 5]

# %%
import numpy as np
x = np.array([0101,1010,0011,1100])
y = x.astype('b')
print(y)
# Out:
#   File "/var/folders/xf/qvg6j60s7hddvx8mt5qky8gr0000gn/T/ipykernel_74030/2776673062.py", line 2
#     x = np.array([0101,1010,0011,1100])
#                      ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
import numpy as np
arr1 = ([3,5,6])
arr2 = ([5,6,9])
for i in arr1:
    for j in arr2:
        if i == j:
            print(i)
# Out:
# 5
# 6

# %%
import numpy as np
x = np.array([3,4,5,6])
y = np.array([3,4,7,9])
new_arr = np.dstack([x,y])

# %%
new_arr
# Out:
# array([[3, 3],
#        [4, 4],
#        [5, 7],
#        [6, 9]])
